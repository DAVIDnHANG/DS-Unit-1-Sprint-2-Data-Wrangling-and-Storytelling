# %% [markdown]
# <a href="https://colab.research.google.com/github/DAVIDnHANG/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/module3-make-explanatory-visualizations/LS_DS_123_Make_Explanatory_Visualizations_AssignmentTurnIn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ASSIGNMENT
#
# ### 1) Replicate the lesson code. I recommend that you [do not copy-paste](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit).
#
# Get caught up to where we got our example in class and then try and take things further. How close to "pixel perfect" can you make the lecture graph?
#
# Once you have something that you're proud of, share your graph in the cohort channel and move on to the second exercise.
#
# ### 2) Reproduce another example from [FiveThityEight's shared data repository](https://data.fivethirtyeight.com/).
#
# **WARNING**: There are a lot of very custom graphs and tables at the above link. I **highly** recommend not trying to reproduce any that look like a table of values or something really different from the graph types that we are already familiar with. Search through the posts until you find a graph type that you are more or less familiar with: histogram, bar chart, stacked bar chart, line chart, [seaborn relplot](https://seaborn.pydata.org/generated/seaborn.relplot.html), etc. Recreating some of the graphics that 538 uses would be a lot easier in Adobe photoshop/illustrator than with matplotlib.
#
# - If you put in some time to find a graph that looks "easy" to replicate you'll probably find that it's not as easy as you thought.
#
# - If you start with a graph that looks hard to replicate you'll probably run up against a brick wall and be disappointed with your afternoon.

# %%
# import it here
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter

# %%
#This one is evenely dividing the number between .5 to 3.5 by 100. 
X = np.linspace(0.5,3.5,100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/.75)/2
Y3=np.random.uniform(Y1,Y2,len(X))

print(Y3)
# Out:
# [1.96662799 1.92704095 3.3844185  2.4334406  1.12079912 2.10579942
#  2.10446677 1.41152301 3.07547361 2.85309837 2.03569394 3.61055435
#  1.12284192 1.38237373 0.69769324 1.57194821 3.32870202 1.37036908
#  0.88745326 0.81975046 3.26781816 3.40282991 2.53646335 2.03169191
#  2.68249797 2.06753192 0.94741517 2.50106873 2.63811988 1.81165084
#  2.16846036 1.84463959 0.87455267 1.61059869 1.20840023 2.3400509
#  1.75217085 1.47868207 2.57758921 1.15471133 2.30720829 0.93683294
#  1.21539518 0.82847206 2.71088628 1.07900847 0.89488129 0.75091715
#  2.46383154 1.71066193 0.76382012 1.93001249 1.82003226 2.48282211
#  2.46406367 0.93911983 1.61470694 1.83395317 2.32899006 0.90222289
#  2.31802656 0.91002693 1.29442057 0.95771791 1.64318927 1.57968379
#  1.12499546 1.44768967 1.31542512 1.92933827 0.90252507 1.28569228
#  1.47188981 1.24397319 1.21687886 1.31538385 2.01263502 1.29439602
#  1.4245502  1.65867078 1.14736551 2.00444288 1.23918291 1.3442049
# ...

# %%
# let say I have a 1 to 6 and want to split it 12 ways.
#I can use this on a graph, inbetween two (3,6) and i want to split that space between x ways.
Way12 = np.linspace(1,6,12)
Way12
# Out:
# array([1.        , 1.45454545, 1.90909091, 2.36363636, 2.81818182,
#        3.27272727, 3.72727273, 4.18181818, 4.63636364, 5.09090909,
#        5.54545455, 6.        ])

# %%
#figsize width height in inches
fig=plt.figure(figsize=(4,4))
#it a 2by2 on grip 2.
ax=fig.add_subplot(1,1,1,aspect=1)
ax2=fig.add_subplot(2,2,4,aspect=1) #ax2

# %% [markdown]
# ![alt text](https://i.stack.imgur.com/AEGXG.png)

# %%
def minor_tick(x,pos):
    if not x%1.0:
      return ""
    return "%.2f" % x
  
#def circle(x,y,radius=.15):
  #from matplotlib.patches import Circle
  #from matplotlib.patheffects import withStroke
  #circle = Circle((x,y), radius, clip_on=False, zorder=10, linewidth=1,edgecolor='black',facecolor=(0,0,0,.125),path_affects=[withStroke(linewidth=5,foreground='w')])
  #ax.add_artist(circle)

# %%
#figsize width height in inches
fig=plt.figure(figsize=(10,10))
#it a 2by2 on grip 2.
ax=fig.add_subplot(1,1,1,aspect=1)


ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

ax.set_xlim(0,4)
ax.set_ylim(0,4)

#ax.tick_params(which='major',width=1.0)
#ax.tick_params(which='major',length=10)
#ax.tick_params(which='minor',width=1.0,labelsize=10)
#ax.tick_params(which='minor',length=5,labelsize=10,labelcolor='.25')

#ax.grid(linestyle="--",linewidth=.5,color='.25',zorder=-10)


ax.plot(X,Y1, c=(.25,.25,1.00),lw=2,label="Blue signal", zorder=10)
ax.plot(X,Y2, c=(1.00,.25,.25), lw=2, label="Red signal",zorder=10)
ax.plot(X,Y3,linewidth=0, marker='o', markerfacecolor='w',markeredgecolor='k')

ax.legend()
plt.show()

# %% [markdown]
# **Can modify inbetween the space of x= (x,1), y(0,4)**

# %%
#figsize width height in inches
fig=plt.figure(figsize=(10,10))
#it a 2by2 on grip 2.
ax=fig.add_subplot(1,1,1,aspect=1)

#
#
ax.xaxis.set_major_locator(MultipleLocator(1.000)) # change the number on x axis
ax.xaxis.set_minor_locator(AutoMinorLocator(4)) #divide what you see inbetween 0,1
ax.yaxis.set_major_locator(MultipleLocator(1))#How many "locater" i want to show on y axis
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

#ax.set_xlim(0,4)
#ax.set_ylim(0,4)

#ax.tick_params(which='major',width=1.0)
#ax.tick_params(which='major',length=10)
#ax.tick_params(which='minor',width=1.0,labelsize=10)
#ax.tick_params(which='minor',length=5,labelsize=10,labelcolor='.25')

#ax.grid(linestyle="--",linewidth=.5,color='.25',zorder=-10)


ax.plot(X,Y1, c=(.25,.25,1.00),lw=2,label="Blue signal", zorder=10)
ax.plot(X,Y2, c=(1.00,.25,.25), lw=2, label="Red signal",zorder=10)
#ax.plot(X,Y3,linewidth=0, marker='o', markerfacecolor='w',markeredgecolor='k')

ax.legend()
plt.show()

# %%
#figsize width height in inches
fig=plt.figure(figsize=(10,10))
#it a 2by2 on grip 2.
ax=fig.add_subplot(1,1,1,aspect=1)

#
#
ax.xaxis.set_major_locator(MultipleLocator(1.000)) # change the number on x axis
ax.xaxis.set_minor_locator(AutoMinorLocator(2)) #divide what you see inbetween 0,1
ax.yaxis.set_major_locator(MultipleLocator(1))#How many "locater" i want to show on y axis
ax.yaxis.set_minor_locator(AutoMinorLocator(2))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

#ax.set_xlim(0,4)
#ax.set_ylim(0,4)

#ax.tick_params(which='major',width=1.0)
#ax.tick_params(which='major',length=10)
#ax.tick_params(which='minor',width=1.0,labelsize=10)
#ax.tick_params(which='minor',length=5,labelsize=10,labelcolor='.25')

#ax.grid(linestyle="--",linewidth=.5,color='.25',zorder=-10)


ax.plot(X,Y1, c=(.25,.25,1.00),lw=2,label="Blue signal", zorder=10)
ax.plot(X,Y2, c=(1.00,.25,.25), lw=2, label="Red signal",zorder=10)
#ax.plot(X,Y3,linewidth=0, marker='o', markerfacecolor='w',markeredgecolor='k')

ax.legend()
plt.show()

# %% [markdown]
# **Figure out what the tick params is**

# %%
#figsize width height in inches
fig=plt.figure(figsize=(10,10))
#it a 2by2 on grip 2.
ax=fig.add_subplot(1,1,1,aspect=1)

#
#
ax.xaxis.set_major_locator(MultipleLocator(1.000)) # change the number on x axis
ax.xaxis.set_minor_locator(AutoMinorLocator(2)) #divide what you see inbetween 0,1
ax.yaxis.set_major_locator(MultipleLocator(1))#How many "locater" i want to show on y axis
ax.yaxis.set_minor_locator(AutoMinorLocator(2))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

#ax.set_xlim(0,4)
#ax.set_ylim(0,4)

ax.tick_params(which='major',width=1.0)
ax.tick_params(which='major',length=10)
ax.tick_params(which='minor',width=1.0,labelsize=10)
ax.tick_params(which='minor',length=5,labelsize=10,labelcolor='.25')

#ax.grid(linestyle="--",linewidth=.5,color='.25',zorder=-10)


ax.plot(X,Y1, c=(.25,.25,1.00),lw=2,label="Blue signal", zorder=10)
ax.plot(X,Y2, c=(1.00,.25,.25), lw=2, label="Red signal",zorder=10)
#ax.plot(X,Y3,linewidth=0, marker='o', markerfacecolor='w',markeredgecolor='k')

ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-25f70161bc21> in <module>()
#       5 #
#       6 #
# ----> 7 ax.xaxis.set_major_locator(MultipleLocator(1.000)) # change the number on x axis
#       8 ax.xaxis.set_minor_locator(AutoMinorLocator(2)) #divide what you see inbetween 0,1
#       9 ax.yaxis.set_major_locator(MultipleLocator(1))#How many "locater" i want to show on y axis
#
# NameError: name 'MultipleLocator' is not defined

# %%
#figsize width height in inches
fig=plt.figure(figsize=(10,10))
#it a 2by2 on grip 2.
ax=fig.add_subplot(1,1,1,aspect=1)

#
#
ax.xaxis.set_major_locator(MultipleLocator(1.000)) # change the number on x axis
ax.xaxis.set_minor_locator(AutoMinorLocator(2)) #divide what you see inbetween 0,1
ax.yaxis.set_major_locator(MultipleLocator(1))#How many "locater" i want to show on y axis
ax.yaxis.set_minor_locator(AutoMinorLocator(2))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

#ax.set_xlim(0,4)
#ax.set_ylim(0,4)

ax.tick_params(which='major',width=7.0)
ax.tick_params(which='major',length=7)
ax.tick_params(which='minor',width=7.0,labelsize=15)
ax.tick_params(which='minor',length=7,labelsize=15,labelcolor='.55')

#ax.grid(linestyle="--",linewidth=.5,color='.25',zorder=-10)


ax.plot(X,Y1, c=(.25,.25,1.00),lw=2,label="Blue signal", zorder=10)
ax.plot(X,Y2, c=(1.00,.25,.25), lw=2, label="Red signal",zorder=10)
#ax.plot(X,Y3,linewidth=0, marker='o', markerfacecolor='w',markeredgecolor='k')

ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-13567832c1ae> in <module>()
#       5 #
#       6 #
# ----> 7 ax.xaxis.set_major_locator(MultipleLocator(1.000)) # change the number on x axis
#       8 ax.xaxis.set_minor_locator(AutoMinorLocator(2)) #divide what you see inbetween 0,1
#       9 ax.yaxis.set_major_locator(MultipleLocator(1))#How many "locater" i want to show on y axis
#
# NameError: name 'MultipleLocator' is not defined

# %%
#figsize width height in inches
fig=plt.figure(figsize=(8,8))
#it a 2by2 on grip 2.
ax=fig.add_subplot(1,1,1,aspect=1)

#
#
ax.xaxis.set_major_locator(MultipleLocator(1.000)) # change the number on x axis
ax.xaxis.set_minor_locator(AutoMinorLocator(2)) #divide what you see inbetween 0,1
ax.yaxis.set_major_locator(MultipleLocator(1))#How many "locater" i want to show on y axis
ax.yaxis.set_minor_locator(AutoMinorLocator(2))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

#ax.set_xlim(0,4)
#ax.set_ylim(0,4)

ax.tick_params(which='major',width=7.0)
ax.tick_params(which='major',length=7)
ax.tick_params(which='minor',width=7.0,labelsize=15)
ax.tick_params(which='minor',length=7,labelsize=15,labelcolor='.55')

#ax.grid(linestyle="--",linewidth=.5,color='.25',zorder=-10)

#lw is the thickness
#zorder = when graph are plotted on top of each other, zorder take prescidents. the higher the number take precidents.
ax.plot(X,Y1, c=(.22,.25,1.00),lw=5,label="blue signal", zorder=3)
ax.plot(X,Y2, c=(1.00,.25,.25), lw=2, label="Red signal",zorder=4)
#ax.plot(X,Y3,linewidth=0, marker='o', markerfacecolor='w',markeredgecolor='k')

def circle(x,y, radius=.15):
  from matplotlib.patches import Circle
  from matplotlib.patheffects import withStroke
  circle = Circle((x,y),radius, clip_on=False, zorder=10, linewidth=1,
                 edgecolor='black', facecolor=(0,0,0,.0125),
                 path_effects=[withStroke(linewidth=5,foreground='w')])
  ax.add_artist(circle)

def text(x,y,text):
  ax.text(x,y,text,backgroundcolor='white',ha='center',va='top',weight='bold',color='blue')
#minor tick
circle(0.50,-0.10)
text(0.50,-0.32,"Minor tick label")

#scatter plot
circle(3.2,1.75)
text(1.20,1.55,"Markers\n(scatter plot)")

#Grid
circle(3.00,3.00)
text(3.00,2.8,"Grid")

#Legend
circle(3.7,3.8)
text(3.70,3.60,"Legend")

#axes
circle(.5,.5)
text(.5,.3,"Axes")

#figure
circle(-.3,.65)
text(-.3,.45,"Figure")

color = 'blue'
#ax.annotate( 'Spines', xy=(4.0,.34), xytext=(3.3,.5),weight='bold',color=color, arrowprops=dict(arrowstle='->',connectionstyle='arc3',color=color))
#ax.annotate('', 'Spines', xy=(3.15,1.1), xytext=(3.3,.5), weight='bold',color=color,arrowprops=dict(arrowstle='->',connectionstyle='arc3',color=color))
#ax.text(4.0, -.4, "matplot",fontsize=10, ha='right',color='.5')

ax.legend()
plt.show()

# %% [markdown]
# how to draw those circle on there

# %%
def circle(x,y, radius=.15):
  from matplotlib.patches import Circle
  from matplotlib.patheffects import withStroke
  circle = Circle((x,y),radius, clip_on=False, zorder=10, linewidth=1,
                 edgecolor='black', facecolor=(0,0,0,.0125),
                 path_effects=[withStroke(linewidth=5,foreground='w')])
  ax.add_artist(circle)

def text(x,y,text):
  ax.text(x,y,text,backgroundcolor='white',ha='center',va='top',weight='bold',color='blue')
#minor tick
circle(0.50,-0.10)
text(0.50,-0.32,"Minor tick label")

#scatter plot
circle(3.2,1.75)
text(1.20,1.55,"Markers\n(scatter plot)")

#Grid
circle(3.00,3.00)
text(3.00,2.8,"Grid")

#Legend
circle(3.7,3.8)
text(3.70,3.60,"Legend")

#axes
circle(.5,.5)
text(.5,.3,"Axes")

#figure
circle(-.3,.65)
text(-.3,.45,"Figure")

color = 'blue'
#ax.annotate( 'Spines', xy=(4.0,.34), xytext=(3.3,.5),weight='bold',color=color, arrowprops=dict(arrowstle='->',connectionstyle='arc3',color=color))
#ax.annotate('', 'Spines', xy=(3.15,1.1), xytext=(3.3,.5), weight='bold',color=color,arrowprops=dict(arrowstle='->',connectionstyle='arc3',color=color))
#ax.text(4.0, -.4, "matplot",fontsize=10, ha='right',color='.5')
plt.show()

# %%
from IPython.display import display, Image
url = 'https://github.com/fivethirtyeither/data/master/inconvenient-sequel'
#https://fivethirtyeither.com/wp-content/uploads/2017/09/mcbtahickey-inconvenient-0830-1.png
example=Image(url=url,width=400)
display(example)
# Out:
# <img src="https://github.com/fivethirtyeither/data/master/inconvenient-sequel" width="400"/>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.patches as patches
import matplotlib.ticker as ticker



fake=pd.Series([38,3,2,1,2,4,6,5,5,33], index=range(1,11))
#fake.grid()
ax = fake.plot.bar(color='orangered',width=0.9);
plt.axis([0,10,0,40])

ax.xaxis.set_major_locator(MultipleLocator(1)) # change the number on x axis
ax.xaxis.set_minor_locator(AutoMinorLocator(1)) #divide what you see inbetween 0,1

ax.yaxis.set_major_locator(MultipleLocator(10))#How many "locater" i want to show on y axis
ax.yaxis.set_minor_locator(AutoMinorLocator(1))
#str format to add %)
fmt = '{x:,.0f}%'
tick=ticker.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
plt.xticks(rotation=25)



plt.text(-1,44,"'An Inconvenient Sequel: Truth To Power is divisive'", fontweight = 'bold', fontsize=11)
plt.text(-1,42,"IMDb ratings for the film as of Aug. 29", fontsize=11)
plt.xlabel("Rating", fontweight = 'bold')
plt.ylabel("Percent of total votes", fontweight = 'bold')
#ax.set_axis_on()
plt.show()

# %% [markdown]
# # STRETCH OPTIONS
#
# ### 1) Reproduce one of the following using the matplotlib or seaborn libraries:
#
# - [thanksgiving-2015](https://fivethirtyeight.com/features/heres-what-your-part-of-america-eats-on-thanksgiving/)
# - [candy-power-ranking](https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/)
# - or another example of your choice!
#
# ### 2) Make more charts!
#
# Choose a chart you want to make, from [Visual Vocabulary - Vega Edition](http://ft.com/vocabulary).
#
# Find the chart in an example gallery of a Python data visualization library:
# - [Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Altair](https://altair-viz.github.io/gallery/index.html)
# - [Matplotlib](https://matplotlib.org/gallery.html)
# - [Pandas](https://pandas.pydata.org/pandas-docs/stable/visualization.html)
#
# Reproduce the chart. [Optionally, try the "Ben Franklin Method."](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit) If you want, experiment and make changes.
#
# Take notes. Consider sharing your work with your cohort!

# %%
# More Work Here
